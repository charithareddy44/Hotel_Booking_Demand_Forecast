# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.show()

# %%
df = pd.read_csv("../data/raw/hotel_bookings_raw.csv")
df.head()
# Out:
#    booking_id    hotel_type  lead_time arrival_month arrival_weekday  \
# 0           1  Resort Hotel         50           May          Sunday
# 1           2    City Hotel         70      February        Thursday
# 2           3  Resort Hotel         47         March          Friday
# 3           4  Resort Hotel         18         April        Saturday
# 4           5  Resort Hotel        261          June       Wednesday
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 0                        3                     1       3       NaN
# 1                        1                     1       1       1.0
# 2                        0                     2       2       0.0
# 3                        1                     8       3       1.0
# 4                        0                     6       3       1.0
#
#      customer_type     adr  is_canceled
# 0         Contract  364.83            0
# 1         Contract  169.58            1
# 2  Transient-Party  355.68            1
# 3  Transient-Party  483.12            1
# 4            Group  272.23            0

# %%
df.shape
# Out:
# (10200, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   booking_id               10200 non-null  int64
#  1   hotel_type               10200 non-null  object
#  2   lead_time                10200 non-null  int64
#  3   arrival_month            10200 non-null  object
#  4   arrival_weekday          10200 non-null  object
#  5   stays_in_weekend_nights  10200 non-null  int64
#  6   stays_in_week_nights     10200 non-null  int64
#  7   adults                   10200 non-null  int64
#  8   children                 7610 non-null   float64
#  9   customer_type            10000 non-null  object
#  10  adr                      9900 non-null   float64
#  11  is_canceled              10200 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 956.4+ KB

# %%
df.isnull().sum()
# Out:
# booking_id                    0
# hotel_type                    0
# lead_time                     0
# arrival_month                 0
# arrival_weekday               0
# stays_in_weekend_nights       0
# stays_in_week_nights          0
# adults                        0
# children                   2590
# customer_type               200
# adr                         300
# is_canceled                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(186)

# %%
df['is_canceled'].value_counts().plot(kind='bar')
plt.title("Cancellation Distribution")
plt.xlabel("Is Canceled")
plt.ylabel("Count")
plt.show()

# %%
df['arrival_month'].value_counts().plot(kind='bar')
plt.title("Bookings per Month")
plt.xlabel("Month")
plt.ylabel("Bookings")
plt.show()

# %%
df['adr'].plot(kind='hist', bins=30)
plt.title("ADR Distribution (with missing values)")
plt.xlabel("ADR")
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation")
plt.show()
